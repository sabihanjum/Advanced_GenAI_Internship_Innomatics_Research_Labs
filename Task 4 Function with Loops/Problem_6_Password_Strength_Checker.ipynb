# %% [markdown]
# ##Problem 6: Password Strength Checker

# %%
def check_password_strength(password):
  has_digit = False
  has_special = False
  special_chars = "@#$"

  #Rule 1 : Minimum length
  if len(password) < 8:
    return "weak Passwrod (Minimum 8 characters required)"

  #loop through character
  for char in password:
    if char.isdigit():
      has_digit = True
    if char in special_chars:
      has_special = True

  if has_digit and has_special:
    return "Strong Password"
  else:
    return "Weak Passwrord (Must contain digit and special character)"

# %%
#example
pwd = "Pass@123"
print(check_password_strength(pwd))
# Out:
# Strong Password
